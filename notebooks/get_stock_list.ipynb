# %%
import boto3 #Amazon AWS Python SDK
from botocore.config import Config #Config for SDK
from dotenv import load_dotenv # Load .ENV file containing protected information
import os # Ability to manage and access neigboring files 
import pandas as pd
import gzip
import io
from collections import defaultdict
from datetime import time
import pytz
from datetime import time
from tqdm import tqdm

# %%
# Make the environment variables available to python from the .env file
load_dotenv()
# Load the environment variables into python variables
ACCESS_KEY = os.getenv("AWS_ACCESS_KEY_ID")
SECRET_KEY = os.getenv("AWS_SECRET_ACCESS_KEY")

# %%
# Initialize a session using the AWS keys
session = boto3.Session( # Session object used to configure users and environment control
    aws_access_key_id=ACCESS_KEY,
    aws_secret_access_key=SECRET_KEY,
)

# %%
# Create a client with session and speficy the endpoint (where the data is located)
s3 = session.client(
    's3', # Connecting to the S3 (Simple Storage Service) specifically (can connect to any aws service here)
    endpoint_url='https://files.polygon.io', # Base url for the service you want to access
    config=Config(signature_version='s3v4'), # Ensures client is using AWS signature Version 4 protocol by prohibiting api requests unless supplied with
                                             # a secret key. Used for hashsing
)
# The previous code is everything needed to accesss the S3 flatfiles, from here you can use commands like list objects or get objects

# %%
# Initialize a paginator for listing objects
paginator = s3.get_paginator('list_objects_v2')

# %%
# Choose the appropriate prefix depending on the data you need:
# - 'global_crypto' for global cryptocurrency data
# - 'global_forex' for global forex data
# - 'us_indices' for US indices data
# - 'us_options_opra' for US options (OPRA) data
# - 'us_stocks_sip' for US stocks (SIP) data
prefix = 'us_stocks_sip/daily_aggs_v1/2022'  # Example: Change this prefix to match your data need
object_keys = []

# List objects using the selected prefix
for page in paginator.paginate(Bucket='flatfiles', Prefix=prefix):
    for obj in page['Contents']:
        print(obj['Key'])
        object_keys.append(obj['Key'])

prefix = 'us_stocks_sip/daily_aggs_v1/2023'

# List objects using the selected prefix
for page in paginator.paginate(Bucket='flatfiles', Prefix=prefix):
    for obj in page['Contents']:
        object_keys.append(obj['Key'])

prefix = 'us_stocks_sip/daily_aggs_v1/2024'

# List objects using the selected prefix
for page in paginator.paginate(Bucket='flatfiles', Prefix=prefix):
    for obj in page['Contents']:
        object_keys.append(obj['Key'])
# Out:
# us_stocks_sip/minute_aggs_v1/2022/01/2022-01-03.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/01/2022-01-04.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/01/2022-01-05.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/01/2022-01-06.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/01/2022-01-07.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/01/2022-01-10.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/01/2022-01-11.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/01/2022-01-12.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/01/2022-01-13.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/01/2022-01-14.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/01/2022-01-18.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/01/2022-01-19.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/01/2022-01-20.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/01/2022-01-21.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/01/2022-01-24.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/01/2022-01-25.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/01/2022-01-26.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/01/2022-01-27.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/01/2022-01-28.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/01/2022-01-31.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/02/2022-02-01.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/02/2022-02-02.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/02/2022-02-03.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/02/2022-02-04.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/02/2022-02-07.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/02/2022-02-08.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/02/2022-02-09.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/02/2022-02-10.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/02/2022-02-11.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/02/2022-02-14.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/02/2022-02-15.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/02/2022-02-16.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/02/2022-02-17.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/02/2022-02-18.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/02/2022-02-22.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/02/2022-02-23.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/02/2022-02-24.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/02/2022-02-25.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/02/2022-02-28.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-01.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-02.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-03.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-04.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-07.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-08.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-09.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-10.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-11.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-14.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-15.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-16.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-17.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-18.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-21.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-22.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-23.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-24.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-25.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-28.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-29.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-30.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/03/2022-03-31.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/04/2022-04-01.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/04/2022-04-04.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/04/2022-04-05.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/04/2022-04-06.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/04/2022-04-07.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/04/2022-04-08.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/04/2022-04-11.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/04/2022-04-12.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/04/2022-04-13.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/04/2022-04-14.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/04/2022-04-18.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/04/2022-04-19.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/04/2022-04-20.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/04/2022-04-21.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/04/2022-04-22.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/04/2022-04-25.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/04/2022-04-26.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/04/2022-04-27.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/04/2022-04-28.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/04/2022-04-29.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/05/2022-05-02.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/05/2022-05-03.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/05/2022-05-04.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/05/2022-05-05.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/05/2022-05-06.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/05/2022-05-09.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/05/2022-05-10.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/05/2022-05-11.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/05/2022-05-12.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/05/2022-05-13.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/05/2022-05-16.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/05/2022-05-17.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/05/2022-05-18.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/05/2022-05-19.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/05/2022-05-20.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/05/2022-05-23.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/05/2022-05-24.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/05/2022-05-25.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/05/2022-05-26.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/05/2022-05-27.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/05/2022-05-31.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/06/2022-06-01.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/06/2022-06-02.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/06/2022-06-03.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/06/2022-06-06.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/06/2022-06-07.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/06/2022-06-08.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/06/2022-06-09.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/06/2022-06-10.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/06/2022-06-13.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/06/2022-06-14.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/06/2022-06-15.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/06/2022-06-16.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/06/2022-06-17.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/06/2022-06-21.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/06/2022-06-22.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/06/2022-06-23.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/06/2022-06-24.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/06/2022-06-27.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/06/2022-06-28.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/06/2022-06-29.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/06/2022-06-30.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/07/2022-07-01.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/07/2022-07-05.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/07/2022-07-06.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/07/2022-07-07.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/07/2022-07-08.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/07/2022-07-11.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/07/2022-07-12.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/07/2022-07-13.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/07/2022-07-14.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/07/2022-07-15.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/07/2022-07-18.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/07/2022-07-19.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/07/2022-07-20.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/07/2022-07-21.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/07/2022-07-22.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/07/2022-07-25.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/07/2022-07-26.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/07/2022-07-27.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/07/2022-07-28.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/07/2022-07-29.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-01.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-02.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-03.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-04.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-05.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-08.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-09.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-10.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-11.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-12.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-15.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-16.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-17.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-18.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-19.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-22.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-23.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-24.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-25.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-26.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-29.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-30.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/08/2022-08-31.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/09/2022-09-01.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/09/2022-09-02.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/09/2022-09-06.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/09/2022-09-07.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/09/2022-09-08.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/09/2022-09-09.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/09/2022-09-12.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/09/2022-09-13.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/09/2022-09-14.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/09/2022-09-15.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/09/2022-09-16.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/09/2022-09-19.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/09/2022-09-20.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/09/2022-09-21.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/09/2022-09-22.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/09/2022-09-23.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/09/2022-09-26.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/09/2022-09-27.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/09/2022-09-28.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/09/2022-09-29.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/09/2022-09-30.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/10/2022-10-03.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/10/2022-10-04.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/10/2022-10-05.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/10/2022-10-06.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/10/2022-10-07.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/10/2022-10-10.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/10/2022-10-11.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/10/2022-10-12.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/10/2022-10-13.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/10/2022-10-14.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/10/2022-10-17.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/10/2022-10-18.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/10/2022-10-19.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/10/2022-10-20.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/10/2022-10-21.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/10/2022-10-24.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/10/2022-10-25.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/10/2022-10-26.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/10/2022-10-27.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/10/2022-10-28.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/10/2022-10-31.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/11/2022-11-01.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/11/2022-11-02.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/11/2022-11-03.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/11/2022-11-04.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/11/2022-11-07.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/11/2022-11-08.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/11/2022-11-09.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/11/2022-11-10.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/11/2022-11-11.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/11/2022-11-14.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/11/2022-11-15.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/11/2022-11-16.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/11/2022-11-17.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/11/2022-11-18.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/11/2022-11-21.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/11/2022-11-22.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/11/2022-11-23.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/11/2022-11-25.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/11/2022-11-28.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/11/2022-11-29.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/11/2022-11-30.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/12/2022-12-01.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/12/2022-12-02.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/12/2022-12-05.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/12/2022-12-06.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/12/2022-12-07.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/12/2022-12-08.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/12/2022-12-09.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/12/2022-12-12.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/12/2022-12-13.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/12/2022-12-14.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/12/2022-12-15.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/12/2022-12-16.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/12/2022-12-19.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/12/2022-12-20.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/12/2022-12-21.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/12/2022-12-22.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/12/2022-12-23.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/12/2022-12-27.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/12/2022-12-28.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/12/2022-12-29.csv.gz
# us_stocks_sip/minute_aggs_v1/2022/12/2022-12-30.csv.gz

# %%
# Market hours in Eastern Time
market_open = time(9, 30)
market_close = time(16, 0)

# Convert timezone?
USE_TIMEZONE_CONVERSION = True  # Set to False if timestamps are already in ET

# Tracks ticker -> list of daily in-market sample counts
ticker_sample_counts = defaultdict(list)

for object_key in tqdm(object_keys):
    # Read the file from S3 into memory
    response = s3.get_object(Bucket='flatfiles', Key=object_key)
    with gzip.GzipFile(fileobj=io.BytesIO(response['Body'].read())) as f:
        df = pd.read_csv(f)

    # Convert timestamp column (from nanoseconds)
    df['timestamp'] = pd.to_datetime(df['window_start'], unit='ns')

    if USE_TIMEZONE_CONVERSION:
        # Assume timestamps are in UTC and convert to US/Eastern
        df['timestamp'] = df['timestamp'].dt.tz_localize('UTC').dt.tz_convert('US/Eastern')

    # Filter only rows during market hours
    df = df[df['timestamp'].dt.time.between(market_open, market_close)]

    # Count in-market samples per ticker
    counts = df.groupby('ticker').size()

    # Store daily count for each ticker
    for ticker, count in counts.items():
        ticker_sample_counts[ticker].append(count)

# Filter: only keep tickers that have the same number of in-market samples each day
valid_tickers = [ticker for ticker, counts in ticker_sample_counts.items() if len(set(counts)) == 1]

print("Valid tickers:", valid_tickers)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 753/753 [56:50<00:00,  4.53s/it]
# Valid tickers: ['CIT', 'CITpB', 'FB', 'MGLN', 'VIAC', 'YSACW', 'ZXIET', 'FXCOU', 'EVSTC', 'SHELw', 'NTEST.L', 'EVGBC', 'EVLMC', 'ALACU', 'BBUCw', 'ESABw', 'CBX', 'GLUrw', 'NTEST.Y', 'NTEST.Z', 'ZVZZC', 'RODI', 'MIMO.WS.C', 'MMM.WD', 'EMPW', 'ADEAV', 'RSFrw', 'ZCZZT', 'ARMKw', 'Kw', 'WPCw', 'WORw', 'CDLRw', 'ROIS', 'XLYO', 'INXBV', 'INXB', 'ILMNV', 'AFCGV', 'SUNSV', 'HHHw', 'LIAE', 'AVKrw', 'LIAG', 'Jw', 'EFFI', 'JHCR', 'LIAF', 'LIAV', 'WXET', 'BRIF', 'EFFE', 'ONEG']

# %%
len(valid_tickers)
# Out:
# 53
